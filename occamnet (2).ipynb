# %%
# !git clone https://github.com/RohanD1369/OccamNet_Public.git
# !cd OccamNet_Public/analytic-and-programs
# Out:
# Cloning into 'OccamNet_Public'...
# remote: Enumerating objects: 601, done.
# remote: Counting objects: 100% (601/601), done.
# remote: Compressing objects: 100% (490/490), done.
# remote: Total 601 (delta 221), reused 434 (delta 89), pack-reused 0 (from 0)
# Receiving objects: 100% (601/601), 18.78 MiB | 11.60 MiB/s, done.
# Resolving deltas: 100% (221/221), done.

# %%
# !pip install numpy scipy tensorflow
# !pip install conda


# Import necessary libraries
import numpy as np
import scipy
import tensorflow as tf

# !conda env create -f environment.yml
# Step 1: Install Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -q -y --prefix /usr/local -c conda-forge conda

# Step 2: Add conda to the system path
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# Step 3: Create and activate a new conda environment
# !conda create -n occamnet python=3.8 numpy scipy tensorflow -y
# !source activate occamnet

# Step 4: Verify the environment
# !conda info --envs
# !which python  # Should point to the Python in the conda environment

# Step 5: Clone the repository and run the model
# !git clone https://github.com/RohanD1369/OccamNet_Public.git
# %cd OccamNet_Public/analytic-and-programs
# Out:
# ...
# ERROR: Ignored the following yanked versions: 3.0.6, 3.5.0, 3.7.0, 3.17.0, 4.0.0, 4.0.1, 4.0.2, 4.0.3, 4.0.4, 4.0.5, 4.0.7, 4.0.8, 4.0.9, 4.1.2, 4.1.6, 4.2.6, 4.2.7, 4.3.13, 4.3.16
# ERROR: Could not find a version that satisfies the requirement conda (from versions: none)
# ERROR: No matching distribution found for conda
# /bin/bash: line 1: conda: command not found
# --2024-08-20 23:56:53--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146836934 (140M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 140.03M   150MB/s    in 0.9s
#
# 2024-08-20 23:56:54 (150 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [146836934/146836934]
# ...

# %%
# !pip install sympy
# !pip install torch
# !pip install numpy
# !pip install matplotlib
# !pip install alive_progress
# !pip install IPython

# %%
# Step 5: Clone the repository and run the model
# !git clone https://github.com/RohanD1369/OccamNet_Public.git
# %cd OccamNet_Public/analytic-and-programs

# %%
# %cd OccamNet_Public/analytic-and-programs

# %%
# !conda init
# !conda activate occamnet

# %%
# !pip install torchvision

# %%
# !pip install ipykernel

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p ./content/experiments/videos/

# %%
# !python run_experiment.py
# Out:
# Traceback (most recent call last):
#   File "/content/OccamNet_Public/analytic-and-programs/OccamNet_Public/analytic-and-programs/run_experiment.py", line 15, in <module>
#     with open(json_file_path, 'r') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/parameters.json'
